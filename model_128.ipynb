# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import Xception, ResNet50
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC
from sklearn.metrics import roc_auc_score, average_precision_score, precision_score, recall_score, f1_score, roc_curve
import matplotlib.pyplot as plt

def build_deepfake_detector_xception(input_shape=(128, 128, 3), learning_rate=0.0001):
    base_model = Xception(weights='imagenet', include_top=False, input_shape=input_shape)
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    predictions = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss='binary_crossentropy',
                  metrics=['accuracy', AUC(name='auc')])
    return model

def build_deepfake_detector_resnet50(input_shape=(128, 128, 3), learning_rate=0.0001):
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss='binary_crossentropy',
                  metrics=['accuracy', AUC(name='auc')])
    return model

def save_model(model, filename="deepfake_model.keras"):
    model.save(filename)
    print(f"Model saved to {filename}")
# Out:
# 2025-06-03 09:47:35.165837: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748944055.348527      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748944055.405831      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
DATA_DIR = "/kaggle/input/faceforensics1600-videospreprocess/data"
IMG_HEIGHT, IMG_WIDTH, CHANNELS = 128, 128, 3
IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
BATCH_SIZE = 32
EPOCHS = 15
sub_dirs = ['train', 'test', 'val']

def create_dataframe(DATA_DIR, sub_dir):
    data = {"file_path": [], "label": []}
    for label_dir, label in zip(['real', 'fake'], [1, 0]):
        folder_path = os.path.join(DATA_DIR, sub_dir, label_dir)
        for img_file in os.listdir(folder_path):
            data["file_path"].append(os.path.join(folder_path, img_file))
            data["label"].append(label)
    return pd.DataFrame(data)

for sub_dir in sub_dirs:
    df = create_dataframe(DATA_DIR, sub_dir)
    csv_path = f"{sub_dir}.csv"
    df.to_csv(csv_path, index=False)
    print(f"Saved {csv_path} with {len(df)} entries.")

train_df = pd.read_csv("train.csv").sample(frac=1, random_state=42).reset_index(drop=True)
valid_df = pd.read_csv("val.csv").sample(frac=1, random_state=42).reset_index(drop=True)
test_df = pd.read_csv("test.csv").sample(frac=1, random_state=42).reset_index(drop=True)

for df in [train_df, valid_df, test_df]:
    df['label'] = df['label'].astype(str)

train_datagen = ImageDataGenerator(rescale=1.0/255, horizontal_flip=True)
datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='file_path',
    y_col='label',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary'
)
valid_generator = datagen.flow_from_dataframe(
    dataframe=valid_df,
    x_col='file_path',
    y_col='label',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False
)
test_generator = datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='file_path',
    y_col='label',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False
)
# Out:
# Saved train.csv with 11448 entries.
# Saved test.csv with 3103 entries.
# Saved val.csv with 1257 entries.
# Found 11448 validated image filenames belonging to 2 classes.
# Found 1257 validated image filenames belonging to 2 classes.
# Found 3103 validated image filenames belonging to 2 classes.

# %%
choice = input("Choose model (1 for Xception, 2 for ResNet50): ")
input_shape = (IMG_HEIGHT, IMG_WIDTH, CHANNELS)
if choice == '1':
    model = build_deepfake_detector_xception(input_shape=input_shape)
elif choice == '2':
    model = build_deepfake_detector_resnet50(input_shape=input_shape)
else:
    raise ValueError("Invalid choice. Use 1 or 2.")

checkpoint_path = '/kaggle/working/final_deepfake_model.keras'
model_checkpoint = ModelCheckpoint(
    checkpoint_path,
    monitor="val_accuracy",
    save_best_only=True,
    mode="max",
    verbose=1
)

history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=EPOCHS,
    callbacks=[model_checkpoint]
)

model.load_weights(checkpoint_path)
save_model(model, "/kaggle/working/final_deepfake_model.keras")
# save_model(model, "final_deepfake_model.keras")
# Out:
# Choose model (1 for Xception, 2 for ResNet50):  1
# Epoch 1/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6461 - auc: 0.7081 - loss: 0.6580
# Epoch 1: val_accuracy improved from -inf to 0.76134, saving model to /kaggle/working/final_deepfake_model.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 104s 160ms/step - accuracy: 0.6464 - auc: 0.7084 - loss: 0.6576 - val_accuracy: 0.7613 - val_auc: 0.8550 - val_loss: 0.4893
# Epoch 2/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9103 - auc: 0.9722 - loss: 0.2131
# Epoch 2: val_accuracy did not improve from 0.76134
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 38s 105ms/step - accuracy: 0.9103 - auc: 0.9722 - loss: 0.2131 - val_accuracy: 0.7582 - val_auc: 0.8351 - val_loss: 0.7905
# Epoch 3/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9554 - auc: 0.9913 - loss: 0.1166
# Epoch 3: val_accuracy improved from 0.76134 to 0.77804, saving model to /kaggle/working/final_deepfake_model.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 39s 109ms/step - accuracy: 0.9554 - auc: 0.9913 - loss: 0.1166 - val_accuracy: 0.7780 - val_auc: 0.8595 - val_loss: 0.8846
# Epoch 4/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9737 - auc: 0.9969 - loss: 0.0667
# Epoch 4: val_accuracy did not improve from 0.77804
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 37s 104ms/step - accuracy: 0.9737 - auc: 0.9969 - loss: 0.0667 - val_accuracy: 0.7733 - val_auc: 0.8558 - val_loss: 0.8098
# Epoch 5/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9822 - auc: 0.9983 - loss: 0.0486
# Epoch 5: val_accuracy improved from 0.77804 to 0.78520, saving model to /kaggle/working/final_deepfake_model.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 39s 108ms/step - accuracy: 0.9822 - auc: 0.9983 - loss: 0.0486 - val_accuracy: 0.7852 - val_auc: 0.8490 - val_loss: 0.9547
# Epoch 6/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9917 - auc: 0.9996 - loss: 0.0232
# Epoch 6: val_accuracy did not improve from 0.78520
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 37s 104ms/step - accuracy: 0.9917 - auc: 0.9996 - loss: 0.0232 - val_accuracy: 0.7852 - val_auc: 0.8515 - val_loss: 1.1165
# Epoch 7/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9912 - auc: 0.9991 - loss: 0.0271
# Epoch 7: val_accuracy improved from 0.78520 to 0.79793, saving model to /kaggle/working/final_deepfake_model.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 39s 108ms/step - accuracy: 0.9912 - auc: 0.9991 - loss: 0.0271 - val_accuracy: 0.7979 - val_auc: 0.8674 - val_loss: 0.8906
# Epoch 8/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9932 - auc: 0.9995 - loss: 0.0209
# Epoch 8: val_accuracy did not improve from 0.79793
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 37s 104ms/step - accuracy: 0.9933 - auc: 0.9995 - loss: 0.0209 - val_accuracy: 0.7884 - val_auc: 0.8593 - val_loss: 1.0644
# Epoch 9/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9924 - auc: 0.9995 - loss: 0.0209
# Epoch 9: val_accuracy did not improve from 0.79793
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 37s 104ms/step - accuracy: 0.9924 - auc: 0.9995 - loss: 0.0209 - val_accuracy: 0.7916 - val_auc: 0.8584 - val_loss: 0.9803
# Epoch 10/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9918 - auc: 0.9986 - loss: 0.0309
# Epoch 10: val_accuracy did not improve from 0.79793
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 37s 104ms/step - accuracy: 0.9918 - auc: 0.9986 - loss: 0.0309 - val_accuracy: 0.7971 - val_auc: 0.8803 - val_loss: 0.8097
# Epoch 11/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9941 - auc: 0.9996 - loss: 0.0173
# Epoch 11: val_accuracy did not improve from 0.79793
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 37s 104ms/step - accuracy: 0.9941 - auc: 0.9996 - loss: 0.0173 - val_accuracy: 0.7963 - val_auc: 0.8589 - val_loss: 1.0130
# Epoch 12/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9951 - auc: 0.9997 - loss: 0.0155
# Epoch 12: val_accuracy did not improve from 0.79793
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 37s 104ms/step - accuracy: 0.9951 - auc: 0.9997 - loss: 0.0155 - val_accuracy: 0.7868 - val_auc: 0.8835 - val_loss: 0.9348
# Epoch 13/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9952 - auc: 0.9992 - loss: 0.0160
# Epoch 13: val_accuracy did not improve from 0.79793
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 37s 104ms/step - accuracy: 0.9952 - auc: 0.9992 - loss: 0.0160 - val_accuracy: 0.7749 - val_auc: 0.8713 - val_loss: 1.1547
# Epoch 14/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9963 - auc: 0.9997 - loss: 0.0123
# Epoch 14: val_accuracy improved from 0.79793 to 0.82737, saving model to /kaggle/working/final_deepfake_model.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 39s 108ms/step - accuracy: 0.9963 - auc: 0.9997 - loss: 0.0123 - val_accuracy: 0.8274 - val_auc: 0.8999 - val_loss: 0.8198
# Epoch 15/15
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9962 - auc: 0.9999 - loss: 0.0106
# Epoch 15: val_accuracy improved from 0.82737 to 0.83373, saving model to /kaggle/working/final_deepfake_model.keras
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 39s 108ms/step - accuracy: 0.9962 - auc: 0.9999 - loss: 0.0106 - val_accuracy: 0.8337 - val_auc: 0.8961 - val_loss: 0.7547
# Model saved to /kaggle/working/final_deepfake_model.keras

# %%
test_generator.reset()
y_true = test_generator.classes
y_pred_prob = model.predict(test_generator, verbose=1).ravel()
y_pred = (y_pred_prob > 0.5).astype(int)

# Metrics
auc_score = roc_auc_score(y_true, y_pred_prob)
map_score = average_precision_score(y_true, y_pred_prob)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print(f"AUC: {auc_score:.4f}")
print(f"MAP: {map_score:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 25s 228ms/step
# AUC: 0.8869
# MAP: 0.8843
# Precision: 0.8227
# Recall: 0.7426
# F1 Score: 0.7806

# %%
fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc_score:.4f}')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.grid()
plt.show()
